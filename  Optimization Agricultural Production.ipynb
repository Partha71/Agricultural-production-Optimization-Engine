# %%
#for manipulations
import numpy as np
import pandas as pd

#for data visualisations
import matplotlib.pyplot as plt
import seaborn as sns

#for interactivity
from ipywidgets import interact

# %%
#lets read the dataset
my_data = pd.read_csv('datasample.csv')

# %%
#lets check the shape of the dataset
print("The shape of my dataset is :",my_data.shape)
# Out:
# The shape of my dataset is : (2200, 8)

# %%
#lets check the head of the dataset
my_data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
#lets check if there is any missing value present in the dataset
my_data.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
#lets check the Crops present in this Dataset
my_data['label'].value_counts()
# Out:
# pigeonpeas     100
# pomegranate    100
# mango          100
# mungbean       100
# banana         100
# chickpea       100
# apple          100
# coffee         100
# orange         100
# grapes         100
# muskmelon      100
# papaya         100
# jute           100
# coconut        100
# mothbeans      100
# maize          100
# lentil         100
# rice           100
# cotton         100
# blackgram      100
# kidneybeans    100
# watermelon     100
# Name: label, dtype: int64

# %%
#lets check the Summary for all the crops 

print("Average Ratio of Nitrogen in the soil : {0:.2f}".format(my_data['N'].mean()))
print("Average Ratio of Phosphorous in the soil : {0:.2f}".format(my_data['P'].mean()))
print("Average Ratio of Potassium in the soil : {0:.2f}".format(my_data['K'].mean()))
print("Average Temperature in Celsius : {0:.2f}".format(my_data['temperature'].mean()))
print("Average Relative Humidity in % : {0:.2f}".format(my_data['humidity'].mean()))
print("Average pH value of the soil : {0:.2f}".format(my_data['ph'].mean()))
print("Average Rainfall in mm : {0:.2f}".format(my_data['rainfall'].mean()))
# Out:
# Average Ratio of Nitrogen in the soil : 50.55
# Average Ratio of Phosphorous in the soil : 53.36
# Average Ratio of Potassium in the soil : 48.15
# Average Temperature in Celsius : 25.62
# Average Relative Humidity in % : 71.48
# Average pH value of the soil : 6.47
# Average Rainfall in mm : 103.46

# %%
#lets check the Summary Statistics for each of the Crops.

@interact
def summary(crops = list(my_data['label'].value_counts().index)):
    x = my_data[my_data['label'] == crops]
    print("---------------------------------------------------------------------------")
    print("Satistics for Nitrogen")
    print("Minimum Nitrogen required :", x["N"].min())
    print("Average Nitrogen required :", x["N"].mean())
    print("Maximum Nitrogen required :", x["N"].max())
    print("---------------------------------------------------------------------------")
    print("Satistics for Phosphorous")
    print("Minimum Phosphorous required :", x["P"].min())
    print("Average Phosphorous required :", x["P"].mean())
    print("Maximum Phosphorous required :", x["P"].max())
    print("---------------------------------------------------------------------------")
    print("Satistics for Potassium")
    print("Minimum Potassium required :", x["K"].min())
    print("Average Potassium required :", x["K"].mean())
    print("Maximum Potassium required :", x["K"].max())
    print("---------------------------------------------------------------------------")
    print("Satistics for Temperature")
    print("Minimum Temperature required : {0:.2f}".format(x["temperature"].min()))
    print("Average Temperature required : {0:.2f}".format(x["temperature"].mean()))
    print("Maximum Temperature required : {0:.2f}".format(x["temperature"].max()))
    print("---------------------------------------------------------------------------")
    print("Satistics for Humidity")
    print("Minimum Humidity required : {0:.2f}".format(x["humidity"].min()))
    print("Average Humidity required : {0:.2f}".format(x["humidity"].mean()))
    print("Maximum Humidity required : {0:.2f}".format(x["humidity"].max()))
    print("---------------------------------------------------------------------------")
    print("Satistics for PH")
    print("Minimum PH required : {0:.2f}".format(x["ph"].min()))
    print("Average PH required : {0:.2f}".format(x["ph"].mean()))
    print("Maximum PH required : {0:.2f}".format(x["ph"].max()))
    print("---------------------------------------------------------------------------")
    print("Satistics for Rainfall")
    print("Minimum Rainfall required : {0:.2f}".format(x["rainfall"].min()))
    print("Average Rainfall required : {0:.2f}".format(x["rainfall"].mean()))
    print("Maximum Rainfall required : {0:.2f}".format(x["rainfall"].max()))
    print("---------------------------------------------------------------------------")
# Out:
# interactive(children=(Dropdown(description='crops', options=('pigeonpeas', 'pomegranate', 'mango', 'mungbean',…

# %%
#lets compare the average Requirement for each crops with average conditions.

@interact
def compare(conditions = ['N','P','K','temperature','ph','humidity','rainfall']):
    print("Average value for", conditions,"is {0:.2f}".format(my_data[conditions].mean()))
    print("--------------------------------------------------------------------------------------------")
    print("Rice : {0:.2f}".format(my_data[(my_data['label']=='rice')][conditions].mean()))
    print("Black Grams : {0:.2f}".format(my_data[my_data['label']=='blackgram'][conditions].mean()))
    print("Banana : {0:.2f}".format(my_data[(my_data['label']=='banana')][conditions].mean()))
    print("Jute : {0:.2f}".format(my_data[(my_data['label']=='jute')][conditions].mean()))
    print("Coconut : {0:.2f}".format(my_data[(my_data['label']=='coconut')][conditions].mean()))
    print("Apple : {0:.2f}".format(my_data[(my_data['label']=='apple')][conditions].mean()))
    print("Papaya : {0:.2f}".format(my_data[(my_data['label']=='papaya')][conditions].mean()))
    print("Muskmelon : {0:.2f}".format(my_data[(my_data['label']=='muskmelon')][conditions].mean()))
    print("Watermelon : {0:.2f}".format(my_data[(my_data["label"] == 'watermelon')][conditions].mean()))
    print("Kidney Beans : {0:.2f}".format(my_data[(my_data["label"] == 'kidneybeans')][conditions].mean()))
    print("Mung Beans: {0:.2f}".format(my_data[(my_data["label"] == 'mungbeanstions')][conditions].mean()))
    print("Oranges : {0:.2f}".format(my_data[(my_data["label"] == 'orange')][conditions].mean()))
    print("Chick Peas : {0:.2f}".format(my_data[(my_data["label"] == 'chickpea')][conditions].mean()))
    print("Lentils : {0:.2f}".format(my_data[(my_data["label"] == 'lentil')][conditions].mean()))
    print("Cotton : {0:.2f}".format(my_data[(my_data["label"] == 'cotton')][conditions].mean()))
    print("Maize : {0:.2f}".format(my_data[(my_data["label"] == 'maize')][conditions].mean()))
    print("Moth Beans : {0:.2f}".format(my_data[(my_data["label"] == 'mothbeans')][conditions].mean()))
    print("Pigeon Peas : {0:.2f}".format(my_data[(my_data["label"] == 'pigeonpeas')][conditions].mean()))
    print("Mango : {0:.2f}".format(my_data[(my_data["label"] == 'mango')][conditions].mean()))
    print("Ponegranate : {0:.2f}".format(my_data[(my_data["label"] == 'ponegranate')][conditions].mean()))
    print("Coffee : {0:.2f}".format(my_data[(my_data["label"] == 'coffee')][conditions].mean()))
# Out:
# interactive(children=(Dropdown(description='conditions', options=('N', 'P', 'K', 'temperature', 'ph', 'humidit…

# %%
#lets make this function more instuitive

@interact
def comparr(conditions = ['N','P','K','temperature','ph','humidity','rainfall']):
    print('Crops which required greatrer than average :', conditions,'\n')
    print(my_data[my_data[conditions] > my_data[conditions].mean()]['label'].unique())
    print('---------------------------------------------------------------------------------')
    print("Crops which require less than average :", conditions,'\n')
    print(my_data[my_data[conditions] <= my_data[conditions].mean()]['label'].unique())
# Out:
# interactive(children=(Dropdown(description='conditions', options=('N', 'P', 'K', 'temperature', 'ph', 'humidit…

# %%
#diplaying the graphs 

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
fig.savefig('test2png.png', dpi=100)
fig.set_size_inches(18.5, 10.5, forward=True)


plt.subplot(2,4,1)
sns.distplot(my_data['N'], color = 'red')
plt.xlabel("Ratio Of Nitrogen", fontsize = 15)
plt.ylabel('Density', fontsize=16)
plt.grid()

plt.subplot(2,4,2)
sns.distplot(my_data['P'], color = 'lightblue')
plt.xlabel("Ratio Of Phosphorous", fontsize = 15)
plt.ylabel('Density', fontsize=16)
plt.grid()

plt.subplot(2,4,3)
sns.distplot(my_data['K'], color = 'darkblue')
plt.xlabel("Ratio Of Potassium", fontsize = 15)
plt.ylabel('Density', fontsize=16)
plt.grid()

plt.subplot(2,4,4)
sns.distplot(my_data['temperature'], color = 'black')
plt.xlabel("Temperature", fontsize = 15)
plt.ylabel('Density', fontsize=16)
plt.grid()

plt.subplot(2,4,5)
sns.distplot(my_data['rainfall'], color = 'grey')
plt.xlabel("Rainfall", fontsize = 15)
plt.ylabel('Density', fontsize=16)
plt.grid()

plt.subplot(2,4,6)
sns.distplot(my_data['humidity'], color = 'lightgreen')
plt.xlabel("Humidity", fontsize = 15)
plt.ylabel('Density', fontsize=16)
plt.grid()

plt.subplot(2,4,7)
sns.distplot(my_data['ph'], color = 'darkgreen')
plt.xlabel("pH Level", fontsize = 15)
plt.ylabel('Density', fontsize=16)
plt.grid()

plt.suptitle('Distribution For Agricultural Conditions', fontsize = 30)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Partha\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Partha\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
#lets find out some interesting facts 

print("Some Interesting Patterns")
print('-------------------------------------------------------------------------------------------------------------------------')
print('Crops which requires very High Ratio Of Nitrogen Content in Soil :', my_data[my_data['N'] > 120]['label'].unique())
print('Crops which requires very High Ratio Of Phosphorous Content in Soil :', my_data[my_data['P'] > 100]['label'].unique())
print('Crops which requires very High Ratio Of Potassium Content in Soil :', my_data[my_data['K'] > 200]['label'].unique())
print('Crops which requires very High Rainfall :', my_data[my_data['rainfall'] > 200]['label'].unique())
print('Crops which requires very Low Temperature :', my_data[my_data['temperature'] < 10]['label'].unique())
print('Crops which requires very High Temperature :', my_data[my_data['temperature'] > 40]['label'].unique())
print('Crops which requires very Low Humidity :', my_data[my_data['humidity'] < 20]['label'].unique())
print('Crops which requires very Low pH :', my_data[my_data['ph'] < 4]['label'].unique())
print('Crops which requires very High pH :', my_data[my_data['ph'] > 9]['label'].unique())
# Out:
# Some Interesting Patterns
# -------------------------------------------------------------------------------------------------------------------------
# Crops which requires very High Ratio Of Nitrogen Content in Soil : ['cotton']
# Crops which requires very High Ratio Of Phosphorous Content in Soil : ['grapes' 'apple']
# Crops which requires very High Ratio Of Potassium Content in Soil : ['grapes' 'apple']
# Crops which requires very High Rainfall : ['rice' 'papaya' 'coconut']
# Crops which requires very Low Temperature : ['grapes']
# Crops which requires very High Temperature : ['grapes' 'papaya']
# Crops which requires very Low Humidity : ['chickpea' 'kidneybeans']
# Crops which requires very Low pH : ['mothbeans']
# Crops which requires very High pH : ['mothbeans']

# %%
#lets understand which crops can grow in summer season, rainy season and winter season

print('Summer Crops')
print(my_data[(my_data['temperature'] > 30) & (my_data['humidity'] > 50)]['label'].unique())
print('--------------------------------------------------------------------------------------------------')
print('Winter Crops')
print(my_data[(my_data['temperature'] < 20) & (my_data['humidity'] > 30)]['label'].unique())
print('--------------------------------------------------------------------------------------------------')
print('Rainy Crops')
print(my_data[(my_data['rainfall'] > 200) & (my_data['humidity'] >30)]['label'].unique())
# Out:
# Summer Crops
# ['pigeonpeas' 'mothbeans' 'blackgram' 'mango' 'grapes' 'orange' 'papaya']
# --------------------------------------------------------------------------------------------------
# Winter Crops
# ['maize' 'pigeonpeas' 'lentil' 'pomegranate' 'grapes' 'orange']
# --------------------------------------------------------------------------------------------------
# Rainy Crops
# ['rice' 'papaya' 'coconut']

# %%
from sklearn.cluster import KMeans

#Removing the labels column
x = my_data.drop(['label'], axis=1)

#selecting all the values of the data
x = x.values

#Checking the shape
print(x.shape)
# Out:
# (2200, 7)

# %%
#Lets determine the Optimum Number Of Clusture within the Dataset

plt.rcParams['figure.figsize'] = (10,4)

wcss = []
for i in range(1 ,11):
    km = KMeans(n_clusters = i, init ='k-means++',max_iter = 300, n_init = 10, random_state = 0)
    km.fit(x)
    wcss.append(km.inertia_)
    
#lets plot the results
plt.plot(range(1,11), wcss)
plt.title('The Elbow Method', fontsize = 30)
plt.xlabel('No. of Clusters')
plt.ylabel('wcss')
plt.show()

# %%
#lets implement the K Means algorithm to perform Clustering analysis
km = KMeans(n_clusters = 4, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
y_means = km.fit_predict(x)

#lets find out the Results 
a = my_data['label']
y_means = pd.DataFrame(y_means)
z = pd.concat([y_means, a], axis=1)
z = z.rename(columns = {0: 'cluster'})

#lets check the Clusters of each Crops
print('Lets check the Results After Applying the K Means Clustering Analysis \n')
print('Crops in First Cluster', z[z['cluster'] == 0]['label'].unique())
print('-----------------------------------------------------------------------------')
print('Crops in Second Cluster', z[z['cluster'] == 1]['label'].unique())
print('-----------------------------------------------------------------------------')
print('Crops in Third Cluster', z[z['cluster'] == 2]['label'].unique())
print('-----------------------------------------------------------------------------')
print('Crops in Fourth Cluster', z[z['cluster'] == 3]['label'].unique())
# Out:
# Lets check the Results After Applying the K Means Clustering Analysis
#
# Crops in First Cluster ['maize' 'chickpea' 'kidneybeans' 'pigeonpeas' 'mothbeans' 'mungbean'
#  'blackgram' 'lentil' 'pomegranate' 'mango' 'orange' 'papaya' 'coconut']
# -----------------------------------------------------------------------------
# Crops in Second Cluster ['maize' 'banana' 'watermelon' 'muskmelon' 'papaya' 'cotton' 'coffee']
# -----------------------------------------------------------------------------
# Crops in Third Cluster ['grapes' 'apple']
# -----------------------------------------------------------------------------
# Crops in Fourth Cluster ['rice' 'pigeonpeas' 'papaya' 'coconut' 'jute' 'coffee']

# %%
#lets split the Dataset for Predictive Modelling

y = my_data['label']
x = my_data.drop(['label'], axis = 1)

print("Shape of x :", x.shape)
print('Shape of y :', y.shape)
# Out:
# Shape of x : (2200, 7)
# Shape of y : (2200,)

# %%
#Lets create Training and Testing Sets for Validation of Results
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

print('The Shape of x train:', x_train.shape)
print('The Shape of x test:', x_test.shape)
print('The Shape of y train:', y_train.shape)
print('The Shape of y test:', y_test.shape)
# Out:
# The Shape of x train: (1760, 7)
# The Shape of x test: (440, 7)
# The Shape of y train: (1760,)
# The Shape of y test: (440,)

# %%
#Lets create a predictive model 

from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
# Out:
# C:\Users\Partha\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#lets evaluate the Model performance 

from sklearn.metrics import confusion_matrix

#lets print confusion matrix first
plt.rcParams['figure.figsize']=(20,10)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot = True, cmap = 'Wistia')
plt.title('Confusion Matrix Of Logistic Regression', fontsize = 30)
plt.show()

# %%
#lets print the classification Report 
from sklearn.metrics import classification_report
cr = classification_report(y_test, y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        18
#       banana       1.00      1.00      1.00        18
#    blackgram       0.86      0.82      0.84        22
#     chickpea       1.00      1.00      1.00        23
#      coconut       1.00      1.00      1.00        15
#       coffee       1.00      1.00      1.00        17
#       cotton       0.89      1.00      0.94        16
#       grapes       1.00      1.00      1.00        18
#         jute       0.84      1.00      0.91        21
#  kidneybeans       1.00      1.00      1.00        20
#       lentil       0.94      0.94      0.94        17
#        maize       0.94      0.89      0.91        18
#        mango       1.00      1.00      1.00        21
#    mothbeans       0.88      0.92      0.90        25
#     mungbean       1.00      1.00      1.00        17
#    muskmelon       1.00      1.00      1.00        23
# ...

# %%
#lets check of the dataset

my_data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
prediction = model.predict((np.array([[90,
                                       40,
                                       40,   
                                       20,
                                       80,
                                       7,
                                       200]])))
print("The Suggested Crop for Given Climatic Condition is :", prediction)
# Out:
# The Suggested Crop for Given Climatic Condition is : ['rice']
